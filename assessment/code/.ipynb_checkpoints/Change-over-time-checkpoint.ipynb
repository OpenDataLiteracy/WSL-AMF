# %%
#import the required libraries
import csv
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
#Open the logfile
#Open an existing file if you want:
df = pd.read_csv('portalLog.csv',encoding='cp1252')

# %%
#Convert date column to datetime
df['download_date']=pd.to_datetime(df['download_date'])

# %%
df['descriptor'].unique()
# Out:
# array(['assetTypes', 'assetCategories', 'availableMetadataComplete',
#        'coreMetadataComplete', 'median', 'mean', 'standardDeviation'],
#       dtype=object)

# %%
dfdataset = df[df['unit']=='dataset']

# %%
sns.set_style("white")
ax = sns.lineplot(x="download_date", y="value", data=dfdataset)
ax.set(xlabel='Date', ylabel='Number of Datasets')
sns.despine(offset=10, trim=True)
plt.xticks(
    rotation=45, 
    horizontalalignment='right'
)
plt.show()

# %%
#Dataset is in the 'long format' https://hackernoon.com/reshaping-data-in-python-fa27dda2ff77
#Might be able to use 'groupby' to make the charts as well, without pivoting
#To make charting easier, pivot it, by descriptor
dftype = df[df['descriptor']=='assetTypes']
dftype = dftype.pivot(index='download_date',columns='unit', values='value')

dfcat = df[df['descriptor']=='assetCategories']
dfcat = dfcat.pivot(index='download_date',columns='unit', values='value')

dfavmeta = df[df['descriptor']=='availableMetadataComplete']
dfavmeta = dfavmeta.pivot(index='download_date',columns='unit', values='value')

dfcometa = df[df['descriptor']=='coreMetadataComplete']
dfcometa = dfcometa.pivot(index='download_date',columns='unit', values='value')

dfmedian = df[df['descriptor']=='median']
dfmedian = dfmedian.pivot(index='download_date',columns='unit', values='value')

dfmean = df[df['descriptor']=='mean']
dfmean = dfmean.pivot(index='download_date',columns='unit', values='value')

# %%
#dfcat['download_date'][:-1]
#dfcat['download_date']
#plt.plot(dfcat['download_date'], dfcat['Agriculture'], marker='', color='grey', linewidth=0.6, alpha=0.3)

# %% [markdown]
# # Plot trends for all categories

# %%
dfcat.reset_index(inplace=True)

# %%
#Check dfcat to see if you actually need to remove an index column
#dfcat.drop(columns=['index'], inplace=True)

# %%
dfcat.head(5)
# Out:
# unit download_date  Agriculture  Consumer Protection  Culture and Community  \
# 0       2019-08-05          1.0                 26.0                    NaN
# 1       2019-09-16          1.0                 31.0                    6.0
# 2       2019-10-27          1.0                 32.0                    9.0
# 3       2020-04-29          1.0                 35.0                   23.0
# 4       2020-07-14          1.0                 37.0                   25.0
#
# unit  Demographics  Economics  Education  Employment  Health  Labor  \
# 0             47.0       53.0      486.0         6.0   663.0   32.0
# 1             47.0       52.0      475.0         6.0   679.0   32.0
# 2             47.0       50.0      472.0         6.0   683.0   32.0
# 3             48.0       49.0      515.0         7.0   812.0   32.0
# 4             52.0       50.0      519.0         7.0   836.0   32.0
#
# unit  Natural Resources & Environment  No Value  Politics  \
# 0                               413.0     799.0      35.0
# 1                               398.0     763.0      36.0
# 2                               398.0     754.0      36.0
# 3                               406.0     815.0      37.0
# 4                               407.0     819.0      37.0
#
# unit  Procurements and Contracts  Public Safety  Recreation  Transportation
# 0                           33.0           41.0         8.0            10.0
# 1                           33.0           41.0         8.0             8.0
# 2                           34.0           41.0         8.0             8.0
# 3                           36.0           42.0         8.0             9.0
# 4                           37.0           42.0         8.0            12.0

# %%
#Graph all the variables against time https://python-graph-gallery.com/125-small-multiples-for-line-chart/
#https://matplotlib.org/3.1.1/gallery/text_labels_and_annotations/date.html
#https://jakevdp.github.io/PythonDataScienceHandbook/04.08-multiple-subplots.html


plt.style.use('seaborn-darkgrid')
plt.rcParams["figure.figsize"] = [16,16]

# create a color palette
palette = plt.get_cmap('tab20b')

fig = plt.figure()
fig.subplots_adjust(hspace=0.7, wspace=0.4)


# multiple line plot
num=0
for column in dfcat.drop('download_date', axis=1): #I think this drop is to get rid of the x axis vlaues
    num+=1
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
    #plt.axes().set_aspect('equal')
    
    # plot every groups, but discreet
    for v in dfcat.drop('download_date', axis=1):
        plt.plot(dfcat['download_date'], dfcat[v], marker='', color='grey', linewidth=0.6, alpha=0.3)
 
    # Plot the lineplot
    plt.plot(dfcat['download_date'], dfcat[column], marker='', color=palette(num), linewidth=2.4, alpha=0.9, label=column)
 
    # Same limits for everybody!
#    plt.xlim(0,10)
#    plt.ylim(0,2000)
    
    datemin = dfcat['download_date'][:1]
    datemax = dfcat['download_date'][-1:]
    plt.xlim(datemin, datemax)
    plt.grid(False)
    plt.xticks()  #Might be able to use this to get fewer dates on the x axis
 
    # Add title
    plt.title(column, loc='left', fontsize=12, fontweight=0, color=palette(num) )
 
# general title
plt.suptitle("Categories", fontsize=13, fontweight=0, color='black', style='italic', y=0.9)



# rotates and right aligns the x labels, and moves the bottom of the
# axes up to make room for them
fig.autofmt_xdate()

# Axis title
#plt.text(0.5, 0.02, 'Time', ha='center', va='center')
#plt.text(0.06, 0.5, 'Note', ha='center', va='center', rotation='vertical')

# %%
df.head(1)
# Out:
#   download_date  descriptor     unit  value
# 0    2019-08-05  assetTypes  dataset  894.0

# %% [markdown]
# ### Use seaborn facet grid to do the same thing

# %%
#Set up the dataframe
cats=df[df['descriptor']=='assetCategories']
cats = cats.copy()
cats['max'] = cats.groupby('unit')['value'].transform('max')
cats.head(5)
# Out:
#    download_date       descriptor                             unit  value  \
# 12    2019-08-05  assetCategories                         No Value  799.0
# 13    2019-08-05  assetCategories                           Health  663.0
# 14    2019-08-05  assetCategories                        Education  486.0
# 15    2019-08-05  assetCategories  Natural Resources & Environment  413.0
# 16    2019-08-05  assetCategories                        Economics   53.0
#
#       max
# 12  819.0
# 13  837.0
# 14  558.0
# 15  428.0
# 16   53.0

# %%
catsmajor = cats.loc[cats['max'] > 200]
catsminor = cats.loc[cats['max'] <= 200]
catsmajor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 12 to 386
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   download_date  32 non-null     datetime64[ns]
#  1   descriptor     32 non-null     object
#  2   unit           32 non-null     object
#  3   value          32 non-null     float64
#  4   max            32 non-null     float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 1.5+ KB

# %%
#Chart Major Categories
sns.set(font_scale=0.8)
with sns.axes_style("ticks"):
    g = sns.FacetGrid(catsmajor, col="unit", margin_titles=True, col_wrap=2, height=3, aspect=1)
g.map(sns.lineplot, "download_date", "value", color='#000000')
g.set_axis_labels("Date", "Assets")
g.set_xticklabels(rotation=45)
g.set_titles('{col_name}')
g.fig.subplots_adjust(wspace=.02, hspace=.2)

# %%
#Chart Minor Categories
with sns.axes_style("ticks"):
    g = sns.FacetGrid(catsminor, col="unit", margin_titles=True, col_wrap=4, height=2)
g.map(sns.lineplot, "download_date", "value")
g.set_axis_labels("Date", "Assets")
g.set_xticklabels(rotation=45)
g.set_titles('{col_name}')
g.fig.subplots_adjust(wspace=.02, hspace=.2)

# %% [markdown]
# # Plot trends for all types

# %%
dftype.columns
# Out:
# Index(['calendar', 'chart', 'datalens', 'dataset', 'federated_href', 'file',
#        'filter', 'form', 'href', 'map', 'story', 'visualization'],
#       dtype='object', name='unit')

# %%
dftype.reset_index(inplace=True)

# %%
#Graph all the variables against time https://python-graph-gallery.com/125-small-multiples-for-line-chart/


plt.style.use('seaborn-darkgrid')
plt.rcParams["figure.figsize"] = [16,16]
# create a color palette
palette = plt.get_cmap('tab20b')


fig = plt.figure()
fig.subplots_adjust(hspace=0.7, wspace=0.4)

 
# multiple line plot
num=0
for column in dftype.drop('download_date', axis=1): #I think this drop is to get rid of the x axis vlaues
    num+=1
 
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # plot every groups, but discreet
    for v in dftype.drop('download_date', axis=1):
        plt.plot(dftype['download_date'], dftype[v], marker='', color='grey', linewidth=0.6, alpha=0.3)
 
    # Plot the lineplot
    plt.plot(dftype['download_date'], dftype[column], marker='', color=palette(num), linewidth=2.4, alpha=0.9, label=column)
 
    datemin = dftype['download_date'][:1]
    datemax = dftype['download_date'][-1:]
    plt.xlim(datemin, datemax)
    plt.grid(False)
    plt.xticks()  #Might be able to use this to get fewer dates on the x axis
 
    # Add title
    plt.title(column, loc='left', fontsize=12, fontweight=0, color=palette(num) )
 
# general title
plt.suptitle("Asset Types", fontsize=13, fontweight=0, color='black', style='italic', y=1.02)
 
# rotates and right aligns the x labels, and moves the bottom of the
# axes up to make room for them
fig.autofmt_xdate()

# %% [markdown]
# ## Plot the number of datasets and number of Available metadata elements

# %%
#dfmedian.plot()
#dfavmeta.plot()
#dfcometa.plot()
dfav = df.loc[df['descriptor']=='availableMetadataComplete']
dfav=dfav.copy() #This gets rid of a setting values on a slice error
dfav['unit'] = pd.to_numeric(dfav['unit'], errors='ignore') #This is needed so the FacetGrid is sorted right
dfav.head()
# Out:
#    download_date                 descriptor  unit  value
# 27    2019-08-05  availableMetadataComplete     2  426.0
# 28    2019-08-05  availableMetadataComplete     6   41.0
# 29    2019-08-05  availableMetadataComplete     8   24.0
# 30    2019-08-05  availableMetadataComplete     5   14.0
# 31    2019-08-05  availableMetadataComplete     0   14.0

# %%
with sns.axes_style("ticks"):
    g = sns.FacetGrid(dfav, col="unit", margin_titles=True, col_wrap=4, height=2)
g.map(sns.lineplot, "download_date", "value", color='#000000')
g.set_axis_labels("Date", "Number of Assets")
g.set_xticklabels(rotation=45)
g.set_titles('{col_name}')
g.fig.subplots_adjust(wspace=.02, hspace=.3)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Number Of Available Metadata Elements Filled In')
# Out:
# Text(0.5, 0.98, 'Number Of Available Metadata Elements Filled In')

# %% [markdown]
# ## Plot number of datasets with various numbers of core metadata elements

# %%
dfcore = df[df['descriptor']=='coreMetadataComplete']
dfcore=dfcore.copy() #This gets rid of a setting values on a slice error
dfcore['unit'] = pd.to_numeric(dfcore['unit'], errors='ignore') #This is needed so the FacetGrid is sorted right
dfcore['percent'] = dfcore.value/11
dfcore.head()
# Out:
#    download_date            descriptor  unit  value    percent
# 37    2019-08-05  coreMetadataComplete     1  435.0  39.545455
# 38    2019-08-05  coreMetadataComplete     3   76.0   6.909091
# 39    2019-08-05  coreMetadataComplete     2   24.0   2.181818
# 40    2019-08-05  coreMetadataComplete     0   15.0   1.363636
# 84    2019-09-16  coreMetadataComplete     1  436.0  39.636364

# %%
with sns.axes_style("ticks"):
    g = sns.FacetGrid(dfcore, col="unit", margin_titles=True, col_wrap=3, height=2)
g.map(sns.lineplot, "download_date", "value", color='#000000')
g.set_axis_labels("Date", "Number of Assets")
g.set_xticklabels(rotation=45)
g.set_titles('{col_name}')
g.fig.subplots_adjust(wspace=.02, hspace=.3)
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Number Of Core Metadata Elements Filled In')
# Out:
# Text(0.5, 0.98, 'Number Of Core Metadata Elements Filled In')
